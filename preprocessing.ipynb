# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
breastcancer = pd.read_csv("original_data/breastcancer.csv", index_col = 0)
pima = pd.read_csv("original_data/pima.csv", index_col = 0)
vowel = pd.read_csv("original_data/vowel.csv", index_col = 0)
abalone = pd.read_csv("original_data/abalone.data", header=None)
dry_bean = pd.read_excel("original_data/dry_bean.xlsx")
wine_quality = pd.read_csv("original_data/wine_quality_white.csv", sep = ';')

# %%
breastcancer.head()
# Out:
#         Id  Cl.thickness  Cell.size  Cell.shape  Marg.adhesion  Epith.c.size  \
# 1  1000025             5          1           1              1             2
# 2  1002945             5          4           4              5             7
# 3  1015425             3          1           1              1             2
# 4  1016277             6          8           8              1             3
# 5  1017023             4          1           1              3             2
#
#    Bare.nuclei  Bl.cromatin  Normal.nucleoli  Mitoses   Class
# 1          1.0            3                1        1  benign
# 2         10.0            3                2        1  benign
# 3          2.0            3                1        1  benign
# 4          4.0            3                7        1  benign
# 5          1.0            3                1        1  benign

# %%
breastcancer = breastcancer.drop('Id', axis = 1)
breastcancer = breastcancer.dropna()
breastcancer = breastcancer.sample(frac = 1)
breastcancer = breastcancer.reset_index().drop('index', axis = 1)
train, test = np.split(breastcancer, [int(0.8 * len(breastcancer))])

train.to_csv("original_data/breastcancer_train.csv", index=False)
test.to_csv("original_data/breastcancer_test.csv", index=False)

# %%
pima = pima.dropna()
pima = pima.sample(frac = 1).reset_index().drop('index', axis = 1)
train, test = np.split(pima, [int(0.8 * len(pima))])
train.to_csv("original_data/pima_train.csv", index=False)
test.to_csv("original_data/pima_test.csv", index=False)

# %%
vowel = vowel.dropna()
vowel = vowel.sample(frac = 1).reset_index().drop('index', axis = 1)
train, test = np.split(vowel, [int(0.8 * len(vowel))])
train.to_csv("original_data/vowel_train.csv", index=False)
test.to_csv("original_data/vowel_test.csv", index=False)

# %%
abalone.columns = ['Sex', 'Length', 'Diameter', 'Height', 
                   'Whole weight', 'Shucked weight', 'Viscera weight',
                   'Shell weight', 'Rings']
abalone = abalone.dropna()
abalone = abalone.sample(frac = 1).reset_index().drop('index', axis = 1)
train, test = np.split(abalone, [int(0.8 * len(abalone))])
train.to_csv("original_data/abalone_train.csv", index=False)
test.to_csv("original_data/abalone_test.csv", index=False)

# %%
dry_bean = dry_bean.dropna()
dry_bean = dry_bean.sample(frac = 1).reset_index().drop('index', axis = 1)
train, test = np.split(dry_bean, [int(0.8 * len(dry_bean))])
train.to_csv("original_data/dry_bean_train.csv", index=False)
test.to_csv("original_data/dry_bean_test.csv", index=False)

# %%
wine_quality = wine_quality.dropna()
wine_quality = wine_quality.sample(frac = 1).reset_index().drop('index', axis = 1)
train, test = np.split(wine_quality, [int(0.8 * len(wine_quality))])
train.to_csv("original_data/wine_quality_train.csv", index=False)
test.to_csv("original_data/wine_quality_test.csv", index=False)

# %%
dry_bean
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      62831   1046.743       356.090610       225.787473      1.577105
# 1      36527    691.877       238.314360       195.398766      1.219631
# 2      43960    805.111       301.120853       187.211082      1.608456
# 3      81804   1103.196       438.347845       238.552533      1.837532
# 4      59841    936.317       354.646935       217.641344      1.629502
# ...      ...        ...              ...              ...           ...
# 13606  46239    833.643       327.159062       181.512956      1.802401
# 13607  41992    763.279       293.224122       182.879522      1.603373
# 13608  46267    854.523       341.614666       174.966070      1.952462
# 13609  41412    750.590       280.106713       188.730485      1.484163
# 13610  35838    684.103       241.756865       189.108451      1.278403
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0          0.773273       64195     282.840792  0.748273  0.978752   0.720616
# 1          0.572478       36865     215.656256  0.765284  0.990831   0.958884
# 2          0.783244       44657     236.583200  0.689569  0.984392   0.852228
# 3          0.838950       82342     322.732223  0.812709  0.993466   0.844654
# 4          0.789551       61068     276.028853  0.692965  0.979908   0.857754
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.831973       46956     242.638256  0.672763  0.984730   0.836100
# 13607      0.781676       42415     231.226891  0.802323  0.990027   0.905753
# 13608      0.858882       47026     242.711710  0.685224  0.983860   0.796221
# 13609      0.738931       41775     229.624467  0.703329  0.991311   0.923699
# 13610      0.622995       36131     213.612637  0.783550  0.991891   0.962300
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.794294      0.005667      0.001392      0.630904      0.995001
# 1         0.904923      0.006524      0.002699      0.818886      0.998739
# 2         0.785675      0.006850      0.001610      0.617286      0.992877
# 3         0.736247      0.005359      0.000971      0.542059      0.996051
# 4         0.778320      0.005926      0.001342      0.605782      0.987123
# ...            ...           ...           ...           ...           ...
# 13606     0.741652      0.007075      0.001320      0.550048      0.991407
# 13607     0.788567      0.006983      0.001666      0.621838      0.997038
# 13608     0.710484      0.007384      0.001161      0.504787      0.985578
# 13609     0.819775      0.006764      0.001884      0.672031      0.997403
# 13610     0.883585      0.006746      0.002536      0.780722      0.998077
#
#           Class
# 0      BARBUNYA
# 1         SEKER
# 2          SIRA
# 3          CALI
# 4          CALI
# ...         ...
# 13606      SIRA
# 13607  DERMASON
# 13608     HOROZ
# 13609  DERMASON
# 13610     SEKER
#
# [13611 rows x 17 columns]
